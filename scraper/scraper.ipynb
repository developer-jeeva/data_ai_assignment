# %% [markdown]
# # Testing Config

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.industrybuying.com/power-tools-641/saws-chasers-17991"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/120 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "lxml")
print(soup.title.text)
# Out:
# Buy Saws & Chasers Online for Industrial Use

# %%
products = soup.find_all("div", class_="IB-prod")
print("Total products:", len(products))
# Out:
# Total products: 0

# %%
for product in products:
    name = product.find("span", class_="IB-prod-name")
    price = product.find("span", class_="price")

    if name and price:
        print(name.text.strip(), price.text.strip())

# %% [markdown]
# # Capturing Products Brand

# %%
brand = product.find("div", class_="brand")
brand = product.find("div", class_="brand")

brand_name = brand.text.strip() if brand else "N/A"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 brand = product.find("div", class_="brand")
#       2 brand = product.find("div", class_="brand")
#       4 brand_name = brand.text.strip() if brand else "N/A"
#
# NameError: name 'product' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import json

url = "https://www.industrybuying.com/power-tools-641/saws-chasers-17991"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "lxml")

# find structured product data
scripts = soup.find_all("script", type="application/ld+json")

print(len(scripts))
# Out:
# 4

# %%
products = []

for script in scripts:
    try:
        data = json.loads(script.string)

        # some pages store list, some store single object
        if isinstance(data, list):
            for item in data:
                if item.get("@type") == "Product":
                    products.append(item)

        elif data.get("@type") == "Product":
            products.append(data)

    except:
        pass

print(len(products))
# Out:
# 1

# %%
for p in products:
    name = p["name"]
    brand = p["brand"]["name"]
    price = p["offers"]["price"]

    print(name, brand, price)
# Out:
# PowerHouse 355 mm Chop saw Machine PHCM355 with 6 Months Warranty Multi Color PowerHouse 5899

# %%
import pandas as pd

rows = []

for p in products:
    rows.append([
        p["name"],
        p["brand"]["name"],
        p["offers"]["price"]
    ])

df = pd.DataFrame(rows, columns=["Product", "Brand", "Price"])

print(df)

# df.to_csv("industrybuying_saws.csv", index=False)
df
# Out:
#                                              Product       Brand  Price
# 0  PowerHouse 355 mm Chop saw Machine PHCM355 wit...  PowerHouse   5899
#                                              Product       Brand  Price
# 0  PowerHouse 355 mm Chop saw Machine PHCM355 wit...  PowerHouse   5899

# %% [markdown]
# # Pagination Test

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0"
}

all_products = []

def extract_products(data):
    products = []

    def traverse(obj):
        if isinstance(obj, dict):
            if obj.get("type") == "PRODUCT_SUMMARY_LIST":
                items = obj["data"]["renderableComponents"]
                for item in items:
                    value = item["value"]

                    name = value["title"]
                    brand = value["productBrand"].replace("By ", "")
                    price = value["pricing"]["prices"][0]["value"]

                    products.append([name, brand, price])

            for v in obj.values():
                traverse(v)

        elif isinstance(obj, list):
            for i in obj:
                traverse(i)

    traverse(data)
    return products


for page in range(1, 18):

    print("Scraping page:", page)

    url = f"https://www.industrybuying.com/power-tools-641/saws-chasers-17991?page={page}"

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")

    scripts = soup.find_all("script")

    target_script = None

    for script in scripts:
        if script.string and "PRODUCT_SUMMARY_LIST" in script.string:
            target_script = script.string
            break

    start = target_script.find("{")
    end = target_script.rfind("}") + 1

    data = json.loads(target_script[start:end])

    page_products = extract_products(data)
    all_products.extend(page_products)

    time.sleep(2)

df = pd.DataFrame(all_products, columns=["Product","Brand","Price"])

print("TOTAL PRODUCTS:", len(df))

# df.to_csv("industrybuying_all_products.csv", index=False)
df
# Out:
# Scraping page: 1
# Scraping page: 2
# Scraping page: 3
# Scraping page: 4
# Scraping page: 5
# Scraping page: 6
# Scraping page: 7
# Scraping page: 8
# Scraping page: 9
# Scraping page: 10
# Scraping page: 11
# Scraping page: 12
# Scraping page: 13
# Scraping page: 14
# Scraping page: 15
# Scraping page: 16
# Scraping page: 17
# TOTAL PRODUCTS: 680
#                                                Product    Brand  Price
# 0             Ingco 1500W 4500 RPM Table Saw , TS15008    Ingco  36579
# 1         Ingco 85 W 1450 rpm Scroll Saw Machine SS852    Ingco   8613
# 2    Ingco WLC15008 Wall Chaser Grinder, with 4 Dis...    Ingco   9439
# 3    Total TAC52644D 150 X 19 X 1.25 mm Reciprocati...    Total    145
# 4         VOLTZ  VZWC -200 800W Wood Table Saw Machine    Voltz   8849
# ..                                                 ...      ...    ...
# 675  XLNT 1100 W Cordless Chainsaw 7800 RPM Speed, ...     XLNT   6017
# 676  Stihl TS-420 Petrol Operated Cut off saw with ...    Stihl  93219
# 677  Omada Hand Held Wall Chaser Cutter 2800W, OMD-...    Omada  16519
# 678  Oem 2400W 2400 Watt Professional Cut Off/Chop ...      OEM   9439
# 679  MAF PRO Miter Saw 2400 W 230 V 5000 RPM 300 mm...  MAF PRO  27139
#
# [680 rows x 3 columns]

# %% [markdown]
# # Final Dataframe

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time
import math

HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

BASE_URL = "https://www.industrybuying.com/power-tools-641/saws-chasers-17991?page={}"


# ---------- STEP 1 : Get total number of products ----------

def get_total_products():

    url = BASE_URL.format(1)

    response = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "lxml")

    scripts = soup.find_all("script")

    for script in scripts:
        if script.string and "PRODUCT_SUMMARY_LIST" in script.string:

            text = script.string
            start = text.find("{")
            end = text.rfind("}") + 1

            data = json.loads(text[start:end])

            # recursively search total count
            def find_total(obj):
                if isinstance(obj, dict):
                    for k, v in obj.items():
                        if k == "totalProductCount":
                            return v
                        result = find_total(v)
                        if result:
                            return result
                elif isinstance(obj, list):
                    for i in obj:
                        result = find_total(i)
                        if result:
                            return result
                return None

            total_products = find_total(data)
            return total_products

    return None


# ---------- STEP 2 : Extract product info ----------

def extract_products(data):

    products = []

    def traverse(obj):

        if isinstance(obj, dict):

            if obj.get("type") == "PRODUCT_SUMMARY_LIST":

                items = obj["data"]["renderableComponents"]

                for item in items:
                    value = item["value"]

                    name = value.get("title")

                    brand = value.get("productBrand", "")
                    brand = brand.replace("By ", "")

                    # Prices
                    selling_price = None
                    tax_price = None

                    for p in value["pricing"]["prices"]:
                        if p["priceType"] == "SELLING_PRICE":
                            selling_price = p.get("value")
                        if p["priceType"] == "TAX_EXCLUSIVE_PRICE":
                            tax_price = p.get("value")

                    # SKU
                    sku = value["addToCart"]["action"]["params"]["sku"]

                    # URL
                    product_url = value["renderableComponents"][0]["action"]["params"]["url"]

                    # Image
                    image_url = value["media"]["images"][0]["url"]

                    # Stock
                    in_stock = value.get("inStock")

                    # Lead time
                    lead_time = value.get("skuLeadTime")

                    # Rating
                    rating = value.get("rating", {}).get("average")

                    # Description
                    description = value.get("description")

                    products.append([
                        name,
                        brand,
                        selling_price,
                        tax_price,
                        sku,
                        product_url,
                        image_url,
                        in_stock,
                        lead_time,
                        rating,
                        description
                    ])

            for v in obj.values():
                traverse(v)

        elif isinstance(obj, list):
            for i in obj:
                traverse(i)

    traverse(data)
    return products


# ---------- STEP 3 : SCRAPE ALL PAGES ----------

def scrape_all_pages():

    total_products = get_total_products()

    if not total_products:
        print("Could not detect total products. Using fallback pages = 20")
        total_pages = 20
    else:
        per_page = 40
        total_pages = math.ceil(total_products / per_page)

    print("Total Products:", total_products)
    print("Total Pages:", total_pages)

    all_products = []

    for page in range(1, total_pages + 1):

        print(f"\nScraping Page {page}/{total_pages}")

        url = BASE_URL.format(page)

        try:
            response = requests.get(url, headers=HEADERS, timeout=20)
            soup = BeautifulSoup(response.text, "lxml")

            scripts = soup.find_all("script")

            target_script = None
            for script in scripts:
                if script.string and "PRODUCT_SUMMARY_LIST" in script.string:
                    target_script = script.string
                    break

            if not target_script:
                print("No data found on page", page)
                continue

            start = target_script.find("{")
            end = target_script.rfind("}") + 1

            data = json.loads(target_script[start:end])

            page_products = extract_products(data)

            print("Products found:", len(page_products))

            all_products.extend(page_products)

            time.sleep(2)  # polite delay

        except Exception as e:
            print("Error on page", page, e)

    return all_products


# ---------- MAIN ----------

if __name__ == "__main__":

    all_products = scrape_all_pages()

    df = pd.DataFrame(all_products, columns=[
        "Product",
        "Brand",
        "Selling Price",
        "Tax Exclusive Price",
        "SKU",
        "Product URL",
        "Image URL",
        "In Stock",
        "Lead Time",
        "Rating",
        "Description"
    ])

    print("\nTOTAL ROWS:", len(df))

    # df.to_csv("industrybuying_complete_dataset.csv", index=False)

    print("\nDataset saved as: industrybuying_complete_dataset.csv")
    print(df)
# Out:
# Total Products: 3
# Total Pages: 1
#
# Scraping Page 1/1
# Products found: 40
#
# TOTAL ROWS: 40
#
# Dataset saved as: industrybuying_complete_dataset.csv
#                                               Product               Brand  \
# 0            Ingco 1500W 4500 RPM Table Saw , TS15008               Ingco
# 1        Ingco 85 W 1450 rpm Scroll Saw Machine SS852               Ingco
# 2   Ingco WLC15008 Wall Chaser Grinder, with 4 Dis...               Ingco
# 3   Total TAC52644D 150 X 19 X 1.25 mm Reciprocati...               Total
# 4        VOLTZ  VZWC -200 800W Wood Table Saw Machine               Voltz
# 5   Dongcheng 150 mm 1400W Electric Groove Cutter/...           Dongcheng
# 6   Voltz Wood Table Saw with 24 & 60 Teeth blades...               Voltz
# 7   Dongcheng 2000 W 3800 RPM Electric Cut-Off Mac...           Dongcheng
# 8   Dewalt 14 Inch Corded Electric Heavy Duty Chop...              Dewalt
# 9             Ingco 5000 RPM 1400W Mitre Saw BMS14007               Ingco
# 10  Ingco 20V 900W Lithium-Ion Chain Saw, CGSLI201...               Ingco
# 11  Dewalt 254mm DW714 1650W OPP Mitre Saw with TC...              Dewalt
# 12  Akari 300 W Heavy Duty Chain Saw Grinder - CSG-NM               AKARI
# 13  Bosch 355 mm Bench Top Cut off Saw GCO 220 Pro...               Bosch
# 14  PowerHouse 355 mm Chop saw Machine PHCM355 wit...          PowerHouse
# 15  VOLTZ VZ-BS230 9 In. Benchtop Band Saw Black (...               Voltz
# 16               Ingco 4800 RPM Circular Saw, CS18538               Ingco
# 17              Bosch  GTS 254 Professional Table Saw               Bosch
# 18  PowerHouse 255 mm Mitre Saw Without Bevel 2200...          PowerHouse
# 19             Ingco 350W Industrial Band Saw BAS3502               Ingco
# 20  Voltz VZWC-200 Table Saw 800W Wood Table Saw o...               Voltz
# 21           Makita MLT100 4300 RPM 43.8 kg Table Saw              Makita
# 22  Voltz 255B 2200W Professional Miter Saw with B...               Voltz
# 23            STANLEY SM18-IN 1800W Sliding Mitre Saw             STANLEY
# 24  Ingco 20V Cordless Jigsaw (Without Battery & C...               Ingco
# 25   Dewalt DWE7492-IN 2000W 254mm Portable Table Saw              Dewalt
# 26            Akari 62CC Petrol Chain Saw, APT-GCS-62               AKARI
# 27  GIGAWATTS 530 mm Blade 2.8 kW Power Gasoline C...           GIGAWATTS
# 28  STANLEY SJ60-IN Variable Speed Pendulum Jigsaw...             STANLEY
# 29        Gaocheng 5000 RPM 2500 W Miter Saw, GC-MS12            Gaocheng
# 30       Bosch GKS 190 Heavy Duty Circular Saw 1400 W               Bosch
# 31  STANLEY 254 mm 1650 W Compound Mitre Saw, SM16-IN             STANLEY
# 32                      IBELL 62 CC Chain Saw, 6218CS               IBELL
# 33  Dongcheng Z1R-FF-110 DZR110 Electric Groove Cu...           Dongcheng
# 34  Malfah Enterprises Scroll Saw for Cutting Wood...  Malfah Enterprises
# 35        Ingco 1600 W 5000 RPM Circular Saw, CS18568               Ingco
# 36  Gaocheng 200 mm Wheel Diameter 800 W Benchtop ...            Gaocheng
# 37               Makita 305 mm 900 W Band Saw LB1200F              Makita
# 38       Elex Gold EX-85061 550 W 500-3000 RPM Jigsaw           Elex Gold
# 39          Xtra Power 650 W 3100 RPM Jig Saw XPT 464          Xtra Power
#
#     Selling Price  Tax Exclusive Price                SKU  \
# 0           36579                30999   POW.SAW.86410832
# 1            8613                 7299  POW.SAW.103033292
# 2            9439                 7999  POW.WAL.105083984
# 3             145                  123   POW.REC.89730797
# 4            8849                 7499   POW.SAW.67632861
# 5            9793                 8299   POW.WAL.55306696
# 6           15339                12999  MAC.BAN.106508270
# 7            8023                 6799   TOO.CUT.73513142
# 8           16519                13999   POW.CHO.66385880
# 9            7787                 6599   POW.MIT.36725842
# 10           8495                 7199   POW.CHA.87280490
# 11          20059                16999   POW.SAW.71223465
# 12           3185                 2699   POW.CHA.47398540
# 13          10973                 9299   POW.CHO.21529895
# 14           5899                 4999   POW.CHO.81521217
# 15          21239                17999   MAC.BAN.46508267
# 16           4483                 3799   POW.SAW.65260951
# 17          28319                23999   POW.SAW.36619456
# 18           6607                 5599   POW.MIT.82065711
# 19          16519                13999   TOO.BAR.36410842
# 20           7905                 6699   MAC.BAN.96508258
# 21          56639                47999      PO.SA0.107562
# 22          10147                 8599   POW.MIT.66499091
# 23          27139                22999   POW.MIT.96599960
# 24           5191                 4399   POW.COR.67365934
# 25          58999                49999   POW.SAW.35316994
# 26           6725                 5699   POW.CHA.97418131
# 27           7315                 6199  POW.CHA.126411330
# 28           5899                 4999   POW.JIG.82218304
# 29          17699                14999  POW.MIT.620143651
# 30          11445                 9699      PO.SA0.107538
# 31          21239                17999   POW.MIT.72884244
# 32           8967                 7599   POW.CHA.28656343
# 33           6489                 5499   POW.MAR.44234398
# 34           7905                 6699  POW.SCR.521022812
# 35           5545                 4699   POW.SAW.42684842
# 36           6843                 5799  POW.TAB.220143468
# 37          87319                73999   POW.SAW.72219597
# 38           1651                 1399      PO.SA0.453535
# 39           5308                 4498   POW.JIG.67679097
#
#                                           Product URL  \
# 0                          /table-saw-ingco-FAM239183
# 1   https://www.industrybuying.com/scroll-saw-ingc...
# 2                       /wall-chasers-ingco-FAM131309
# 3                  /reciprocating-saw-total-FAM135243
# 4   https://www.industrybuying.com/table-saw-voltz...
# 5   https://www.industrybuying.com/wall-chasers-do...
# 6                          /table-saw-voltz-FAM192114
# 7                       /chop-saw-dongcheng-FAM137478
# 8                          /chop-saw-dewalt-FAM109755
# 9                          /miter-saw-ingco-FAM131157
# 10                         /chain-saw-ingco-FAM199167
# 11                        /miter-saw-dewalt-FAM109401
# 12  https://www.industrybuying.com/chain-saw-akari...
# 13                          /chop-saw-bosch-FAM108785
# 14  https://www.industrybuying.com/chop-saw-powerh...
# 15  https://www.industrybuying.com/band-saw-voltz-...
# 16  https://www.industrybuying.com/circular-saw-in...
# 17  https://www.industrybuying.com/table-saw-bosch...
# 18  https://www.industrybuying.com/miter-saw-power...
# 19  https://www.industrybuying.com/band-saw-ingco-...
# 20  https://www.industrybuying.com/table-saw-voltz...
# 21                        /table-saw-makita-FAM250964
# 22                         /miter-saw-voltz-FAM130268
# 23  https://www.industrybuying.com/miter-saw-stanl...
# 24  https://www.industrybuying.com/jig-saw-ingco-P...
# 25  https://www.industrybuying.com/table-saw-dewal...
# 26                         /chain-saw-akari-FAM197694
# 27  https://www.industrybuying.com/chain-saw-gigaw...
# 28                         /jig-saw-stanley-FAM120146
# 29                      /miter-saw-gaocheng-FAM144098
# 30  https://www.industrybuying.com/circular-saw-bo...
# 31  https://www.industrybuying.com/miter-saw-stanl...
# 32                         /chain-saw-ibell-FAM132616
# 33                  /wall-chasers-dongcheng-FAM142394
# 34  https://www.industrybuying.com/scroll-saw-malf...
# 35                      /circular-saw-ingco-FAM131053
# 36                      /table-saw-gaocheng-FAM144777
# 37  https://www.industrybuying.com/band-saw-makita...
# 38  https://www.industrybuying.com/jig-saw-elex-go...
# 39                      /jig-saw-xtra-power-FAM126127
#
#                                             Image URL  In Stock  \
# 0   //static1.industrybuying.com/products/power-to...      True
# 1   //static1.industrybuying.com/products/power-to...      True
# 2   //static1.industrybuying.com/products/power-to...      True
# 3   //static1.industrybuying.com/products/power-to...      True
# 4   //static1.industrybuying.com/products/power-to...      True
# 5   //static1.industrybuying.com/products/power-to...      True
# 6   //static1.industrybuying.com/products/power-to...      True
# 7   //static1.industrybuying.com/products/power-to...      True
# 8   //static1.industrybuying.com/products/power-to...      True
# 9   //static1.industrybuying.com/products/power-to...      True
# 10  //static1.industrybuying.com/products/power-to...      True
# 11  //static1.industrybuying.com/products/power-to...      True
# 12  //static1.industrybuying.com/products/power-to...      True
# 13  //static1.industrybuying.com/products/power-to...      True
# 14  //static1.industrybuying.com/products/power-to...      True
# 15  //static1.industrybuying.com/products/power-to...      True
# 16  //static1.industrybuying.com/products/power-to...      True
# 17  //static1.industrybuying.com/products/power-to...      True
# 18  //static1.industrybuying.com/products/power-to...      True
# 19  //static1.industrybuying.com/products/power-to...      True
# 20  //static1.industrybuying.com/products/power-to...      True
# 21  //static1.industrybuying.com/products/power-to...      True
# 22  //static1.industrybuying.com/products/power-to...      True
# 23  //static1.industrybuying.com/products/power-to...      True
# 24  //static1.industrybuying.com/products/power-to...      True
# 25  //static1.industrybuying.com/products/power-to...      True
# 26  //static1.industrybuying.com/products/power-to...      True
# 27  //static1.industrybuying.com/products/power-to...      True
# 28  //static1.industrybuying.com/products/power-to...      True
# 29  //static1.industrybuying.com/products/power-to...      True
# 30  //static1.industrybuying.com/products/power-to...      True
# 31  //static1.industrybuying.com/products/power-to...      True
# 32  //static1.industrybuying.com/products/power-to...      True
# 33  //static1.industrybuying.com/products/power-to...      True
# 34  //static1.industrybuying.com/products/power-to...      True
# 35  //static1.industrybuying.com/products/power-to...      True
# 36  //static1.industrybuying.com/products/power-to...      True
# 37  //static1.industrybuying.com/products/power-to...      True
# 38  //static1.industrybuying.com/products/power-to...      True
# 39  //static1.industrybuying.com/products/power-to...      True
#
#                Lead Time  Rating  \
# 0                   None     0.0
# 1                   None     0.0
# 2                   None     0.0
# 3                   None     0.0
# 4                   None     0.0
# 5                   None     0.0
# 6                   None     0.0
# 7                   None     0.0
# 8                   None     0.0
# 9                   None     0.0
# 10                  None     0.0
# 11                  None     0.0
# 12                  None     0.0
# 13                  None     0.0
# 14                  None     4.8
# 15                  None     0.0
# 16                  None     0.0
# 17                  None     5.0
# 18                  None     4.9
# 19                  None     5.0
# 20                  None     0.0
# 21                  None     4.7
# 22                  None     0.0
# 23                  None     0.0
# 24                  None     0.0
# 25                  None     5.0
# 26                  None     0.0
# 27   Ships within 4 days     0.0
# 28   Ships within 3 days     0.0
# 29  Ships within 30 days     0.0
# 30                  None     0.0
# 31                  None     0.0
# 32                  None     0.0
# 33   Ships within 6 days     0.0
# 34                  None     0.0
# 35                  None     0.0
# 36                  None     0.0
# 37  Ships within 10 days     0.0
# 38  Ships within 15 days     0.0
# 39  Ships within 30 days     0.0
#
#                                           Description
# 0   The Ingco Table Saw is a powerful and reliable...
# 1   The Ingco Scroll Saw Machine is a highly preci...
# 2   The Ingco Wall Chaser is a specialized tool de...
# 3   The Total 1/2 Inch Reciprocating Saw Blade is ...
# 4   VOLTZ Table Saw Wood Table Saw (800W), Woodwor...
# 5   The Dongcheng 150 mm 1400W Electric Groove Cut...
# 6   Experience precision and power with the Voltz ...
# 7   Dongcheng Cut-Off Machine 355 x 3 x 25.4 mm Wh...
# 8   Unleash Precision and Efficiency with High-Qua...
# 9   The Ingco Mitre Saw is a versatile and efficie...
# 10  The Ingco Cordless Chain Saw is a versatile an...
# 11  Introducing Mitre Saws: Unleashing Precision a...
# 12  Akari's Heavy Duty Chain Saw Grinder CSG-NM is...
# 13  The Bosch Professional Metal Cut Off Saw is a ...
# 14  Powerhouse Chop Saw High power abrasion protec...
# 15  The VOLTZ VZ-BS0903 is a powerful and reliable...
# 16  Private Label SKU Voltage: 220-240V~50/60Hz In...
# 17  The Bosch GTS 254 T is a table saw with a maxi...
# 18  Powerhouse mitre saw is lightweight and compac...
# 19  Features:- This Industrial Band Saw is best fo...
# 20  VOLTZ VZWC-200 Table Saw 800W Wood Table Saw i...
# 21  The Makita Table Saw with a blade diameter ran...
# 22  The VOLTZ 2200W Professional Miter Saw, model ...
# 23  The sliding mitre saw has a powerful 1800W mot...
# 24  The Ingco 20V Cordless Jigsaw is powered by a ...
# 25  Extremely Accurate &amp; Easy to Use Saw. Port...
# 26  The Akari Chain Saw is a high-performance, ver...
# 27  The GIGAWATTS 530 mm Blade Gasoline Chainsaw, ...
# 28  The Stanley Variable Speed Jigsaw is a versati...
# 29  Gaocheng Miter Saw is a precision-engineered p...
# 30  Saws are tools that are used in every area of ...
# 31
# 32  iBELL is a dynamic brand renowned for its inno...
# 33  Dongcheng 1600W Wall Chaser is a robust and ve...
# 34  Malfah Enterprises Scroll Saw for Cutting Wood...
# 35  The Ingco Circular Saw is a versatile and powe...
# 36  Gaocheng 800 W Benchtop Table Saw is a compact...
# 37  305 mm (12") 900 W Band Saw<br>305mm Band Saw ...
# 38  The Elex Gold Jig Saw, EX85061 consists of an ...
# 39  The Xtra Power Jig Saw from the XPT Series is ...

# %% [markdown]
# # Main Category Formation

# %%
import requests
import pandas as pd
from datetime import datetime
import time

URL = "https://www.industrybuying.com/api/catalog/getProductListing"

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json"
}

all_products = []

def scrape_page(page):

    payload = {
        "pageUri": "/power-tools-641",
        "pageNumber": page
    }

    response = requests.post(URL, json=payload, headers=HEADERS)

    if response.status_code != 200:
        print("Failed page", page)
        return

    data = response.json()

    products = data.get("products", [])

    for p in products:

        record = {
            "entity_name": p.get("title"),
            "category": "Power Tools",
            "location": "India",
            "selling_price": p.get("sellingPrice"),
            "rating_count": p.get("ratingCount"),
            "source_url": "https://www.industrybuying.com" + p.get("productUrl"),
            "scraped_at": datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
        }

        all_products.append(record)


# paginate
for page in range(1, 3):
    print("Scraping page", page)
    scrape_page(page)
    time.sleep(1)

df = pd.DataFrame(all_products)
print("Total rows:", len(df))

df.to_csv("raw_data.csv", index=False)
# Out:
# Scraping page 1
# Failed page 1
# Scraping page 2
# Failed page 2
# Total rows: 0

# %%
import requests
from bs4 import BeautifulSoup

BASE = "https://www.industrybuying.com"
url = BASE + "/power-tools-641"

headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "lxml")

categories = set()

for a in soup.find_all("a", href=True):
    href = a["href"]

    # actual subcategory pattern
    if href.startswith("/power-tools-641/") and href.count("/") == 2:
        categories.add(BASE + href)

for c in sorted(categories):
    print(c)

print("\nTotal categories:", len(categories))
# Out:
# https://www.industrybuying.com/power-tools-641/all-products
# https://www.industrybuying.com/power-tools-641/angle-grinders-889
# https://www.industrybuying.com/power-tools-641/armatures-5299
# https://www.industrybuying.com/power-tools-641/battery-chargers-17945
# https://www.industrybuying.com/power-tools-641/bench-drill-press-17525
# https://www.industrybuying.com/power-tools-641/blowers-heat-guns-17940
# https://www.industrybuying.com/power-tools-641/building-construction-19707
# https://www.industrybuying.com/power-tools-641/carbon-brush-14349
# https://www.industrybuying.com/power-tools-641/chain-saw-16503
# https://www.industrybuying.com/power-tools-641/chisels-bull-points-6307
# https://www.industrybuying.com/power-tools-641/chop-saw-896
# https://www.industrybuying.com/power-tools-641/circular-saw-17775
# https://www.industrybuying.com/power-tools-641/concrete-vibrators-17975
# https://www.industrybuying.com/power-tools-641/cordless-drills-16333
# https://www.industrybuying.com/power-tools-641/cordless-impact-wrench-17950
# https://www.industrybuying.com/power-tools-641/cordless-power-tools-16332
# https://www.industrybuying.com/power-tools-641/cordless-screwdriver-17954
# https://www.industrybuying.com/power-tools-641/cordless-tool-battery-and-chargers-2285
# https://www.industrybuying.com/power-tools-641/cutters-17957
# https://www.industrybuying.com/power-tools-641/die-grinders-17063
# https://www.industrybuying.com/power-tools-641/drain-cleaner-18354
# https://www.industrybuying.com/power-tools-641/drills-17960
# https://www.industrybuying.com/power-tools-641/electric-blower-17153
# https://www.industrybuying.com/power-tools-641/electric-drills-17146
# https://www.industrybuying.com/power-tools-641/electric-hammers-breakers-17969
# https://www.industrybuying.com/power-tools-641/electric-impact-wrench-17160
# https://www.industrybuying.com/power-tools-641/electric-planer-17157
# https://www.industrybuying.com/power-tools-641/electric-router-16268
# https://www.industrybuying.com/power-tools-641/electric-screw-drivers-17965
# https://www.industrybuying.com/power-tools-641/electric-trimmer-17983
# https://www.industrybuying.com/power-tools-641/gear-pinion-14350
# https://www.industrybuying.com/power-tools-641/grinders-vibrators-17971
# https://www.industrybuying.com/power-tools-641/heavy-duty-lathe-machines-14541
# https://www.industrybuying.com/power-tools-641/impact-drills-886
# https://www.industrybuying.com/power-tools-641/impact-wrench-16765
# https://www.industrybuying.com/power-tools-641/industrial-drilling-machine-19708
# https://www.industrybuying.com/power-tools-641/laminate-trimmers-2346
# https://www.industrybuying.com/power-tools-641/orbital-sander-17988
# https://www.industrybuying.com/power-tools-641/polishers-17989
# https://www.industrybuying.com/power-tools-641/power-tool-accessories-4109
# https://www.industrybuying.com/power-tools-641/rotary-hammers-909
# https://www.industrybuying.com/power-tools-641/routers-and-trimmers-17982
# https://www.industrybuying.com/power-tools-641/sanders-polishers-17984
# https://www.industrybuying.com/power-tools-641/saws-chasers-17991
# https://www.industrybuying.com/power-tools-641/spares-14348
# https://www.industrybuying.com/power-tools-641/spares-and-accessories-19692
# https://www.industrybuying.com/power-tools-641/torque-wrenches-accessories-18004
# https://www.industrybuying.com/power-tools-641/wrenches-18002
#
# Total categories: 48

# %%
import requests
from bs4 import BeautifulSoup

BASE = "https://www.industrybuying.com"
url = BASE + "/categories"

headers = {"User-Agent": "Mozilla/5.0"}

soup = BeautifulSoup(requests.get(url, headers=headers).text, "lxml")

main_categories = set()

for a in soup.find_all("a", href=True):
    href = a["href"]

    # pattern: /power-tools-641
    if href.startswith("/") and "-" in href and href.split("-")[-1].isdigit():
        if href.count("/") == 1:
            main_categories.add(BASE + href)

for c in sorted(main_categories):
    print(c)

print("\nTotal main categories:", len(main_categories))
# Out:
# Total main categories: 0

# %% [markdown]
# # Final Code Test

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time
from datetime import datetime

BASE = "https://www.industrybuying.com"
HEADERS = {"User-Agent": "Mozilla/5.0"}

MAX_CATEGORIES = 10
MAX_PER_CATEGORY = 50

# -----------------------------------
# 1. Get subcategories
# -----------------------------------
def get_subcategories():

    url = BASE + "/power-tools-641"
    soup = BeautifulSoup(requests.get(url, headers=HEADERS).text, "lxml")

    subcats = []

    for a in soup.find_all("a", href=True):
        href = a["href"]

        if href.startswith("/power-tools-641/") and href.count("/") == 2:
            if "all-products" not in href:
                full_url = BASE + href
                if full_url not in subcats:
                    subcats.append(full_url)

    # limit to 10
    return subcats[:MAX_CATEGORIES]


# -----------------------------------
# 2. Extract product JSON
# -----------------------------------
def extract_products(data, page_url, category_name):

    products = []

    def traverse(obj):

        if isinstance(obj, dict):

            if obj.get("type") == "PRODUCT_SUMMARY_LIST":

                for item in obj["data"]["renderableComponents"]:

                    value = item["value"]

                    record = {
                        "category": category_name,
                        "page_url": page_url,
                        "scraped_at": datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S"),
                        "raw_product_json": json.dumps(value)   # FULL PRODUCT DATA
                    }

                    products.append(record)

            for v in obj.values():
                traverse(v)

        elif isinstance(obj, list):
            for i in obj:
                traverse(i)

    traverse(data)
    return products

# -----------------------------------
# 3. Scrape one subcategory
# -----------------------------------
def scrape_subcategory(subcat_url):

    print("\nScraping:", subcat_url)

    category_name = subcat_url.split("/")[-1]
    collected = []
    page = 1

    while len(collected) < MAX_PER_CATEGORY:

        url = f"{subcat_url}?page={page}"
        print("  Page:", page)

        response = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(response.text, "lxml")

        # find hydration script
        target_script = None
        for script in soup.find_all("script"):
            if script.string and "PRODUCT_SUMMARY_LIST" in script.string:
                target_script = script.string
                break

        if not target_script:
            break

        start = target_script.find("{")
        end = target_script.rfind("}") + 1
        data = json.loads(target_script[start:end])

        page_products = extract_products(data, url, category_name)

        if not page_products:
            break

        for p in page_products:
            if len(collected) < MAX_PER_CATEGORY:
                collected.append(p)
            else:
                break

        page += 1
        time.sleep(2)

    print("  Collected:", len(collected))
    return collected


# -----------------------------------
# 4. Main
# -----------------------------------
def main():

    dataset = []

    subcategories = get_subcategories()
    print("Selected subcategories:", len(subcategories))

    for sub in subcategories:
        products = scrape_subcategory(sub)
        dataset.extend(products)

    df = pd.DataFrame(dataset)

    print("\nTOTAL ROWS:", len(df))
    df.to_csv("../raw_data.csv", index=False)
    print("Saved raw_data.csv")


if __name__ == "__main__":
    main()
# Out:
# Selected subcategories: 10
#
# Scraping: https://www.industrybuying.com/power-tools-641/cordless-power-tools-16332
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/cordless-drills-16333
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/battery-chargers-17945
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/cordless-impact-wrench-17950
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/building-construction-19707
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/heavy-duty-lathe-machines-14541
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/industrial-drilling-machine-19708
#   Page: 1
#   Page: 2
#   Collected: 34
#
# Scraping: https://www.industrybuying.com/power-tools-641/drain-cleaner-18354
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/drills-17960
#   Page: 1
#   Page: 2
#   Collected: 50
#
# Scraping: https://www.industrybuying.com/power-tools-641/electric-drills-17146
#   Page: 1
#   Page: 2
#   Collected: 50
#
# TOTAL ROWS: 484
# Saved raw_data.csv

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
